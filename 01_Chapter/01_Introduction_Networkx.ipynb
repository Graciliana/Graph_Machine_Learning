# %% [markdown]
# <a href="https://colab.research.google.com/github/Graciliana/Graph_Machine_Learning/blob/main/01_Introduction_Networkx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

import os
import sys

sys.path.append(f"{os.getcwd()}/..")

#from utils import draw_graph
